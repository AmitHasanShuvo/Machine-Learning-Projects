# %% [markdown]
# Author: Kazi Amit Hasan <br>
# Department of Computer Science & Engineering,<br>
# Rajshahi University of Engineering & Technology (RUET)<br>
# Website: https://amithasanshuvo.github.io/<br>
# Linkedin: https://www.linkedin.com/in/kazi-amit-hasan-514443140/<br>
# Email: kaziamithasan89@gmail.com
#
# <hr>
# References:
# 1. https://www.kaggle.com/codeblogger/convolutional-neural-network-cnn-tutorial
# 2. https://www.kaggle.com/rushikesh0203/mnist-sign-language-recognition-cnn-99-94-accuracy

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
train=pd.read_csv('/kaggle/input/sign-language-mnist/sign_mnist_train.csv')
test=pd.read_csv('/kaggle/input/sign-language-mnist/sign_mnist_test.csv')

# %%
train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 164.4 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7172 entries, 0 to 7171
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 43.0 MB

# %%
train.shape
# Out:
# (27455, 785)

# %%
test.shape
# Out:
# (7172, 785)

# %%
labels = train['label'].values
plt.figure(figsize = (14,8))
sns.countplot(x =labels)

# %%
X_train = train.drop(["label"],axis=1)
X_test = test.drop(["label"],axis=1)
Y_train = train['label']
Y_test = test['label']
del train['label']
del test['label']

# %%
X_train = X_train/255.0
X_test = X_test/255.0
X_train.shape
X_test.shape
# Out:
# (7172, 784)

# %%
X_train = X_train.values.reshape(-1,28,28,1)
X_test = X_test.values.reshape(-1,28,28,1)
X_train.shape
X_test.shape
# Out:
# (7172, 28, 28, 1)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binrizer = LabelBinarizer()
Y_train = label_binrizer.fit_transform(Y_train)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

print("x_train shape",X_train.shape)
print("x_test shape",X_val.shape)
print("y_train shape",Y_train.shape)
print("y_test shape",Y_val.shape)
# Out:
# x_train shape (21964, 28, 28, 1)
# x_test shape (5491, 28, 28, 1)
# y_train shape (21964, 24)
# y_test shape (5491, 24)

# %%
from sklearn.metrics import confusion_matrix
import itertools
import tensorflow as tf

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop,Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau


model = tf.keras.models.Sequential([
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu',padding = 'same', input_shape=(28, 28, 1)),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(128, (3, 3),padding = 'same', activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(512, (3, 3),padding = 'same', activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        
                        tf.keras.layers.Conv2D(512, (3, 3),padding = 'same', activation='relu'),
                        tf.keras.layers.Flatten(),
                        tf.keras.layers.Dense(512, activation='relu'),
                        tf.keras.layers.Dense(24, activation='softmax')])
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_41 (Conv2D)           (None, 28, 28, 64)        640
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 7, 7, 512)         590336
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 3, 3, 512)         0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 4608)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               2359808
# _________________________________________________________________
# dense_23 (Dense)             (None, 24)                12312
# =================================================================
# Total params: 5,396,760
# Trainable params: 5,396,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
#optimizer = Adam(lr=0.003, beta_1=0.9, beta_2=0.999)

model.compile( optimizer='rmsprop' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
epochs = 50 
batch_size = 200

# %%
#Data augmentation
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False,  
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False, 
        zca_whitening=False,
        rotation_range=15, 
        zoom_range = 0.5,
        width_shift_range=0.15,  
        height_shift_range=0.15, 
        horizontal_flip=True,  
        vertical_flip=False)  

datagen.fit(X_train)

# %%
history = model.fit_generator(datagen.flow(X_train,Y_train, batch_size=batch_size),epochs = epochs, validation_data = (X_val,Y_val), steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Train for 109 steps, validate on 5491 samples
# Epoch 1/50
# 109/109 [==============================] - 8s 74ms/step - loss: 3.2108 - accuracy: 0.0594 - val_loss: 3.0205 - val_accuracy: 0.1195
# Epoch 2/50
# 109/109 [==============================] - 7s 63ms/step - loss: 2.8080 - accuracy: 0.1473 - val_loss: 2.2594 - val_accuracy: 0.3107
# Epoch 3/50
# 109/109 [==============================] - 7s 61ms/step - loss: 2.3211 - accuracy: 0.2702 - val_loss: 1.6354 - val_accuracy: 0.4507
# Epoch 4/50
# 109/109 [==============================] - 7s 67ms/step - loss: 1.8312 - accuracy: 0.4089 - val_loss: 1.1040 - val_accuracy: 0.6536
# Epoch 5/50
# 109/109 [==============================] - 7s 63ms/step - loss: 1.4183 - accuracy: 0.5321 - val_loss: 0.6352 - val_accuracy: 0.8126
# Epoch 6/50
# 109/109 [==============================] - 7s 61ms/step - loss: 1.0644 - accuracy: 0.6440 - val_loss: 0.3485 - val_accuracy: 0.8911
# Epoch 7/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.8312 - accuracy: 0.7192 - val_loss: 0.2837 - val_accuracy: 0.9069
# Epoch 8/50
# 109/109 [==============================] - 7s 65ms/step - loss: 0.6572 - accuracy: 0.7804 - val_loss: 0.1596 - val_accuracy: 0.9479
# Epoch 9/50
# 109/109 [==============================] - 8s 69ms/step - loss: 0.5418 - accuracy: 0.8169 - val_loss: 0.2903 - val_accuracy: 0.8946
# Epoch 10/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.4500 - accuracy: 0.8487 - val_loss: 0.1757 - val_accuracy: 0.9319
# Epoch 11/50
# 109/109 [==============================] - 7s 62ms/step - loss: 0.3798 - accuracy: 0.8713 - val_loss: 0.1024 - val_accuracy: 0.9623
# Epoch 12/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.3275 - accuracy: 0.8900 - val_loss: 0.0744 - val_accuracy: 0.9736
# Epoch 13/50
# 109/109 [==============================] - 7s 65ms/step - loss: 0.2949 - accuracy: 0.9028 - val_loss: 0.0385 - val_accuracy: 0.9873
# Epoch 14/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.2563 - accuracy: 0.9153 - val_loss: 0.0288 - val_accuracy: 0.9898
# Epoch 15/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.2249 - accuracy: 0.9228 - val_loss: 0.0705 - val_accuracy: 0.9730
# Epoch 16/50
# 109/109 [==============================] - 7s 62ms/step - loss: 0.2059 - accuracy: 0.9316 - val_loss: 0.0177 - val_accuracy: 0.9956
# Epoch 17/50
# 109/109 [==============================] - 8s 70ms/step - loss: 0.1795 - accuracy: 0.9411 - val_loss: 0.0149 - val_accuracy: 0.9953
# Epoch 18/50
# 109/109 [==============================] - 7s 67ms/step - loss: 0.1679 - accuracy: 0.9445 - val_loss: 0.0052 - val_accuracy: 0.9991
# Epoch 19/50
# 109/109 [==============================] - 7s 61ms/step - loss: 0.1617 - accuracy: 0.9453 - val_loss: 0.0280 - val_accuracy: 0.9894
# Epoch 20/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.1418 - accuracy: 0.9522 - val_loss: 0.0109 - val_accuracy: 0.9960
# Epoch 21/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.1488 - accuracy: 0.9524 - val_loss: 0.0079 - val_accuracy: 0.9969
# Epoch 22/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.1318 - accuracy: 0.9578 - val_loss: 0.0428 - val_accuracy: 0.9831
# Epoch 23/50
# 109/109 [==============================] - 7s 67ms/step - loss: 0.1254 - accuracy: 0.9581 - val_loss: 0.0065 - val_accuracy: 0.9978
# Epoch 24/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.1121 - accuracy: 0.9618 - val_loss: 0.0077 - val_accuracy: 0.9967
# Epoch 25/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.1127 - accuracy: 0.9644 - val_loss: 0.0080 - val_accuracy: 0.9969
# Epoch 26/50
# 109/109 [==============================] - 7s 67ms/step - loss: 0.1128 - accuracy: 0.9637 - val_loss: 0.0107 - val_accuracy: 0.9958
# Epoch 27/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.1032 - accuracy: 0.9671 - val_loss: 0.0017 - val_accuracy: 0.9998
# Epoch 28/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0991 - accuracy: 0.9686 - val_loss: 0.0038 - val_accuracy: 0.9982
# Epoch 29/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0970 - accuracy: 0.9691 - val_loss: 0.0017 - val_accuracy: 0.9995
# Epoch 30/50
# 109/109 [==============================] - 7s 62ms/step - loss: 0.0863 - accuracy: 0.9724 - val_loss: 0.0090 - val_accuracy: 0.9975
# Epoch 31/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.0894 - accuracy: 0.9727 - val_loss: 0.0012 - val_accuracy: 0.9995
# Epoch 32/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.0905 - accuracy: 0.9713 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 33/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.0865 - accuracy: 0.9721 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 34/50
# 109/109 [==============================] - 8s 70ms/step - loss: 0.0747 - accuracy: 0.9748 - val_loss: 0.0043 - val_accuracy: 0.9985
# Epoch 35/50
# 109/109 [==============================] - 7s 67ms/step - loss: 0.0818 - accuracy: 0.9739 - val_loss: 0.0243 - val_accuracy: 0.9925
# Epoch 36/50
# 109/109 [==============================] - 7s 60ms/step - loss: 0.0757 - accuracy: 0.9758 - val_loss: 9.0077e-04 - val_accuracy: 0.9998
# Epoch 37/50
# 109/109 [==============================] - 7s 65ms/step - loss: 0.0770 - accuracy: 0.9759 - val_loss: 0.0038 - val_accuracy: 0.9984
# Epoch 38/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0728 - accuracy: 0.9764 - val_loss: 0.0010 - val_accuracy: 0.9996
# Epoch 39/50
# 109/109 [==============================] - 7s 61ms/step - loss: 0.0747 - accuracy: 0.9763 - val_loss: 2.4464e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0708 - accuracy: 0.9784 - val_loss: 6.0256e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 109/109 [==============================] - 7s 62ms/step - loss: 0.0754 - accuracy: 0.9753 - val_loss: 0.0052 - val_accuracy: 0.9980
# Epoch 42/50
# 109/109 [==============================] - 8s 71ms/step - loss: 0.0717 - accuracy: 0.9771 - val_loss: 3.1334e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 109/109 [==============================] - 7s 67ms/step - loss: 0.0695 - accuracy: 0.9782 - val_loss: 0.0393 - val_accuracy: 0.9924
# Epoch 44/50
# 109/109 [==============================] - 7s 62ms/step - loss: 0.0648 - accuracy: 0.9797 - val_loss: 0.0021 - val_accuracy: 0.9989
# Epoch 45/50
# 109/109 [==============================] - 7s 66ms/step - loss: 0.0670 - accuracy: 0.9788 - val_loss: 8.0665e-04 - val_accuracy: 0.9998
# Epoch 46/50
# 109/109 [==============================] - 7s 64ms/step - loss: 0.0603 - accuracy: 0.9803 - val_loss: 0.0025 - val_accuracy: 0.9989
# Epoch 47/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0647 - accuracy: 0.9808 - val_loss: 0.0050 - val_accuracy: 0.9989
# Epoch 48/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0634 - accuracy: 0.9806 - val_loss: 0.0034 - val_accuracy: 0.9993
# Epoch 49/50
# 109/109 [==============================] - 7s 63ms/step - loss: 0.0578 - accuracy: 0.9818 - val_loss: 0.0069 - val_accuracy: 0.9976
# Epoch 50/50
# 109/109 [==============================] - 7s 61ms/step - loss: 0.0652 - accuracy: 0.9799 - val_loss: 0.0057 - val_accuracy: 0.9982

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
